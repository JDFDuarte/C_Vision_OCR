# %%
from paddleocr import PaddleOCR
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Initialize PaddleOCR
ocr = PaddleOCR(use_angle_cls=True, lang='en')

def process_math_expression(image_path):
    # Read the image
    img = cv2.imread(image_path)
    
    # Perform OCR
    result = ocr.ocr(img, cls=True)
    
    # Extract recognized text and bounding boxes
    boxes = [line[0] for line in result[0]]
    texts = [line[1][0] for line in result[0]]
    
    # Sort the results from left to right
    sorted_results = sorted(zip(boxes, texts), key=lambda x: x[0][0][0])
    
    # Extract the mathematical expression
    math_expression = ''.join(text for _, text in sorted_results)
    
    # Draw bounding boxes on the image
    for box in boxes:
        box = np.array(box).astype(np.int32).reshape((-1, 1, 2))
        cv2.polylines(img, [box], True, (0, 255, 0), 2)
    
    # Display the result using matplotlib
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.title('Detected Math Expression')
    plt.axis('off')
    plt.show()
    
    return math_expression
# Out:
# [2024/10/26 18:07:32] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\joana/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\joana/.paddleocr/whl\\rec\\en\\en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_nu
# ...

# %%
image_path = 'C:/Users/joana/OneDrive/Desktop/HSLU/3rd_semester/CV/C_Vision_OCR/data/img_six.png'
extracted_expression = process_math_expression(image_path)
print("Extracted mathematical expression:", extracted_expression)
# Out:
# [2024/10/26 18:07:33] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.0304868221282959
# [2024/10/26 18:07:33] ppocr DEBUG: cls num  : 1, elapsed : 0.015058517456054688
# [2024/10/26 18:07:34] ppocr DEBUG: rec_res num  : 1, elapsed : 0.04110574722290039
# Extracted mathematical expression: 262+513

# %%
image_path = 'C:/Users/joana/OneDrive/Desktop/HSLU/3rd_semester/CV/C_Vision_OCR/data/img_one.png'
extracted_expression = process_math_expression(image_path)
print("Extracted mathematical expression:", extracted_expression)
# Out:
# [2024/10/26 18:07:34] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.028798341751098633
# [2024/10/26 18:07:34] ppocr DEBUG: cls num  : 1, elapsed : 0.01185464859008789
# [2024/10/26 18:07:34] ppocr DEBUG: rec_res num  : 1, elapsed : 0.04130053520202637
# Extracted mathematical expression: h+6

# %%
image_path = 'C:/Users/joana/OneDrive/Desktop/HSLU/3rd_semester/CV/C_Vision_OCR/data/img_five.png'
extracted_expression = process_math_expression(image_path)
print("Extracted mathematical expression:", extracted_expression)
# Out:
# [2024/10/26 18:08:28] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.12389922142028809
# [2024/10/26 18:08:28] ppocr DEBUG: cls num  : 1, elapsed : 0.01797795295715332
# [2024/10/26 18:08:28] ppocr DEBUG: rec_res num  : 1, elapsed : 0.04150700569152832
# Extracted mathematical expression: 53

# %%
image_path = 'C:/Users/joana/OneDrive/Desktop/HSLU/3rd_semester/CV/C_Vision_OCR/data/img_eleven.png'
extracted_expression = process_math_expression(image_path)
print("Extracted mathematical expression:", extracted_expression)
# Out:
# [2024/10/26 18:07:40] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.15487313270568848
# [2024/10/26 18:07:40] ppocr DEBUG: cls num  : 3, elapsed : 0.09000873565673828
# [2024/10/26 18:07:40] ppocr DEBUG: rec_res num  : 3, elapsed : 0.23528504371643066
# Extracted mathematical expression: 53642

# %%
image_path = 'C:/Users/joana/OneDrive/Desktop/HSLU/3rd_semester/CV/C_Vision_OCR/data/img_nine.png'
extracted_expression = process_math_expression(image_path)
print("Extracted mathematical expression:", extracted_expression)
# Out:
# [2024/10/26 18:07:43] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11490964889526367
# [2024/10/26 18:07:43] ppocr DEBUG: cls num  : 1, elapsed : 0.010338306427001953
# [2024/10/26 18:07:43] ppocr DEBUG: rec_res num  : 1, elapsed : 0.03183293342590332
# Extracted mathematical expression: q0/5

# %%
image_path = 'C:/Users/joana/OneDrive/Desktop/HSLU/3rd_semester/CV/C_Vision_OCR/data/img_thirteen.png'
extracted_expression = process_math_expression(image_path)
print("Extracted mathematical expression:", extracted_expression)
# Out:
# [2024/10/26 18:07:45] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.21726512908935547
# [2024/10/26 18:07:45] ppocr DEBUG: cls num  : 1, elapsed : 0.05152153968811035
# [2024/10/26 18:07:45] ppocr DEBUG: rec_res num  : 1, elapsed : 0.040059566497802734
# Extracted mathematical expression: 9637
